# %% [markdown]
# <a href="https://colab.research.google.com/github/brunoma-cpu/Ejercicios-Python/blob/main/BrunoMill%C3%A1n_Problemas13_11_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input('Un Número Cualquiera: '))
pasos=[]
while n != 0:
  if n % 2 != 0:
    n=n-1
    pasos.append(n)
  else:
    n=n/2
    pasos.append(n)
print(len(pasos))
# Out:
# Un Número Cualquiera: 14
# 6

# %%
N=int(input('Un Número Cualquiera: '))
while N != 0:
  if N % 2 != 0:
    N=N-1
    print(N)
  else:
    N=N/2
    print(N)
# Out:
# Un Número Cualquiera: 14
# 7.0
# 6.0
# 3.0
# 2.0
# 1.0
# 0.0

# %%
a=int(input('a= '))
b=int(input('b= '))
c=int(input('c= '))
d=int(input('d= '))
e=int(input('e= '))
list1=[a,b,c,d,e]
list2=[a]
x=0
y=0
while len(list2) < 5:
  y= list1[x+1] + list2[x]
  list2.append(y)
  x=x+1

print(list1)
print(list2)
# Out:
# a= 3
# b= 1
# c= 2
# d= 10
# e= 1
# [3, 1, 2, 10, 1]
# [3, 4, 6, 16, 17]
