# %% [markdown]
# <a href="https://colab.research.google.com/github/brunoma-cpu/Ejercicios-Python/blob/main/Problemas13_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input('Un Número Cualquiera: '))
pasos=[]
while n != 0:
  if n % 2 != 0:
    n=n-1
    pasos.append(n)
  else:
    n=n/2
    pasos.append(n)
print(len(pasos))
# Out:
# Un Número Cualquiera: 14
# 6

# %%
N=int(input('Un Número Cualquiera: '))
while N != 0:
  if N % 2 != 0:
    N=N-1
    print(N)
  else:
    N=N/2
    print(N)
# Out:
# Un Número Cualquiera: 14
# 7.0
# 6.0
# 3.0
# 2.0
# 1.0
# 0.0
